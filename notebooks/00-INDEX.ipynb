# %% [markdown]
# # 🎓 Hamrah Academy Prompt Engineering Workshop
#
# ## Tutorial Index & Navigation Guide
#
# Welcome to the Hamrah Academy Prompt Engineering Workshop! This notebook serves as your guide to navigate through all available tutorials and resources.
#
# ---
#
# ## 📚 Table of Contents
#
# ### **Module 1: Foundations** (Beginner - Week 1-2)
# Learn the basics of prompt engineering and how to work with LLMs.
#
# - **[01-Introduction to Prompt Engineering](./01-introduction.ipynb)**
#   - What is prompt engineering?
#   - Why it matters
#   - Basic principles and best practices
#   - Your first prompt
#   - **Duration**: ~30 minutes
#
# - **[02-Core Prompting Techniques](./02-core-techniques.ipynb)**
#   - Clarity and specificity
#   - Context and examples
#   - Asking for step-by-step thinking
#   - Output formatting
#   - **Duration**: ~45 minutes
#
# ---
#
# ### **Module 2: Intermediate** (Intermediate - Week 3-4)
# Master advanced prompting strategies and real-world applications.
#
# - **[03-Few-Shot Learning](./03-few-shot-learning.ipynb)**
#   - Learning from examples
#   - One-shot vs few-shot vs zero-shot
#   - Selecting effective examples
#   - Practical demonstrations
#   - **Duration**: ~50 minutes
#
# - **[04-Chain-of-Thought Prompting](./04-chain-of-thought.ipynb)**
#   - Breaking down complex problems
#   - Step-by-step reasoning
#   - Improving accuracy
#   - Real-world examples
#   - **Duration**: ~45 minutes
#
# - **[05-Mathematical Reasoning with LLMs](./05-math-llm.ipynb)** ⭐ *Currently Available*
#   - Solving math problems with AI
#   - Algebraic reasoning
#   - Advanced problem-solving
#   - **Duration**: ~60 minutes
#
# ---
#
# ### **Module 3: Advanced** (Advanced - Week 5-6)
# Explore cutting-edge techniques and optimization strategies.
#
# - **[06-Role-Playing & Personas](./06-role-playing.ipynb)**
#   - Adopting specific personas
#   - System prompts and instructions
#   - Creating specialized AI assistants
#   - **Duration**: ~40 minutes
#
# - **[07-Retrieval-Augmented Generation (RAG)](./07-rag.ipynb)**
#   - Combining external knowledge
#   - Document retrieval
#   - Fact-grounding with LLMs
#   - **Duration**: ~50 minutes
#
# - **[08-Optimization & Troubleshooting](./08-optimization.ipynb)**
#   - Debugging poor outputs
#   - Token optimization
#   - Cost reduction strategies
#   - Performance tuning
#   - **Duration**: ~45 minutes
#
# ---
#
# ### **Special Topics**
#
# - **[Capstone Project](./capstone-project.ipynb)**
#   - Build your own AI application
#   - Integrate multiple techniques
#   - Real-world problem solving
#   - **Duration**: ~2-3 hours
#
# ---
#
# ## 🗺️ Learning Paths
#
# ### For **Complete Beginners**
# ```
# 01-Introduction → 02-Core Techniques → 03-Few-Shot → 04-Chain-of-Thought → Capstone
# ```
# Estimated time: **3-4 hours**
#
# ### For **Intermediate Learners**
# ```
# 02-Core Techniques → 03-Few-Shot → 04-Chain-of-Thought → 05-Math LLM → 06-Role-Playing → Capstone
# ```
# Estimated time: **5-6 hours**
#
# ### For **Advanced Users**
# ```
# 04-Chain-of-Thought → 05-Math LLM → 07-RAG → 08-Optimization → Capstone
# ```
# Estimated time: **4-5 hours**
#
# ### For **Specific Topics**
# - **Math/Science**: 05-Math-LLM → 08-Optimization
# - **Content Generation**: 02-Core-Techniques → 06-Role-Playing
# - **Knowledge Apps**: 07-RAG → 08-Optimization
# - **Problem Solving**: 04-Chain-of-Thought → 05-Math-LLM
#
# ---
#
# ## 🚀 Quick Start
#
# ### 1. **Installation**
# ```bash
# # Clone and setup (see SETUP.md for details)
# git clone https://github.com/Baaabaei/hamrah_academy_prompt_engineering_workshop.git
# cd hamrah_academy_prompt_engineering_workshop
# pip install -r requirements.txt
# ```
#
# ### 2. **Launch Jupyter**
# ```bash
# jupyter notebook
# ```
#
# ### 3. **Start Learning**
# - Open this index notebook
# - Click on a tutorial to get started
# - Follow along and experiment
#
# ---
#
# ## 📊 Prerequisites & Requirements
#
# | Requirement | Details |
# |---|---|
# | **Python** | 3.8 or higher |
# | **Libraries** | jupyter, openai, python-dotenv, pandas, numpy |
# | **API Key** | OpenAI API key (get from https://platform.openai.com/api-keys) |
# | **Time** | 30 min to 10+ hours depending on path |
# | **Cost** | Minimal (depends on API usage) |
#
# ---
#
# ## 💡 Learning Tips
#
# ✅ **DO:**
# - Follow tutorials sequentially within each module
# - Experiment with code and prompts
# - Modify examples to test your understanding
# - Take notes and bookmark important concepts
# - Practice on your own problems
#
# ❌ **DON'T:**
# - Skip fundamentals if you're new
# - Copy-paste without understanding
# - Skip the exercises
# - Give up if prompts don't work first try!
#
# ---
#
# ## 🤝 Contributing
#
# Want to improve these tutorials? See [CONTRIBUTING.md](../CONTRIBUTING.md) for how to:
# - Report issues
# - Suggest improvements
# - Add new notebooks
# - Fix bugs
#
# ---
#
# ## 📖 Additional Resources
#
# ### Official Documentation
# - [OpenAI API Documentation](https://platform.openai.com/docs/api-reference)
# - [OpenAI Prompt Engineering Guide](https://platform.openai.com/docs/guides/prompt-engineering)
# - [OpenAI Cookbook](https://github.com/openai/openai-cookbook)
#
# ### Research Papers
# - [Chain-of-Thought Prompting](https://arxiv.org/abs/2201.11903)
# - [Few-Shot Learning with LLMs](https://arxiv.org/abs/2005.14165)
# - [Retrieval-Augmented Generation](https://arxiv.org/abs/2005.11401)
#
# ### Useful Tools
# - [LangChain](https://python.langchain.com/) - LLM framework
# - [LlamaIndex](https://www.llamaindex.ai/) - Data indexing for RAG
# - [Prompt Flow](https://microsoft.github.io/promptflow/) - Workflow management
#
# ---
#
# ## ❓ FAQ
#
# **Q: Do I need to know Python?**
# ```
# A: Basic Python knowledge helps, but not required. Each notebook explains concepts.
# ```
#
# **Q: Can I skip modules?**
# ```
# A: You can jump around, but some advanced tutorials reference foundational concepts.
# ```
#
# **Q: How much will this cost?**
# ```
# A: OpenAI API costs vary. Free tier gives you $5 credits. Typical tutorial costs <$1.
# ```
#
# **Q: Can I modify these notebooks?**
# ```
# A: Yes! These are MIT licensed. Fork, modify, and share freely.
# ```
#
# **Q: What LLMs can I use?**
# ```
# A: Examples use OpenAI, but techniques apply to any LLM (Claude, Gemini, etc.)
# ```
#
# ---
#
# ## 🎓 Course Timeline
#
# ### Week 1-2: Foundations
# - Complete: 01 & 02
# - Key Skills: Basic prompting, clarity, context
# - Project: Simple chatbot
#
# ### Week 3-4: Intermediate
# - Complete: 03, 04, 05
# - Key Skills: Few-shot learning, reasoning, math solving
# - Project: Problem-solving assistant
#
# ### Week 5-6: Advanced
# - Complete: 06, 07, 08, Capstone
# - Key Skills: Specialization, knowledge integration, optimization
# - Project: Production-ready application
#
# ---
#
# ## 📞 Support & Community
#
# - **Issues**: [GitHub Issues](https://github.com/Baaabaei/hamrah_academy_prompt_engineering_workshop/issues)
# - **Discussions**: [GitHub Discussions](https://github.com/Baaabaei/hamrah_academy_prompt_engineering_workshop/discussions)
# - **Email**: Your contact here
#
# ---
#
# ## 🌟 Next Steps
#
# 1. **Start Learning**: Click on a tutorial from the list above
# 2. **Code Along**: Type out examples, don't copy-paste
# 3. **Experiment**: Modify prompts and observe results
# 4. **Build**: Create your own applications
# 5. **Share**: Tell us about your projects!
#
# ---
#
# ## 📝 Your Learning Journey
#
# Track your progress:
# - [ ] Module 1: Foundations
# - [ ] Module 2: Intermediate
# - [ ] Module 3: Advanced
# - [ ] Capstone Project
# - [ ] Share your work!
#
# ---
#
# **Happy Learning! 🚀**
#
# *Last Updated: July 2026 | Maintained by [@Baaabaei](https://github.com/Baaabaei)*
